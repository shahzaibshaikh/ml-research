# %%
# %cd "F:\University\Master's Thesis\Datasets\rnd"
# Out:
# F:\University\Master's Thesis\Datasets\rnd

# %%
# %pip install "u8darts[notorch]"
# Out:
# Collecting u8darts[notorch]Note: you may need to restart the kernel to use updated packages.
#
#   Downloading u8darts-0.27.2-py3-none-any.whl.metadata (49 kB)
#      ---------------------------------------- 0.0/49.9 kB ? eta -:--:--
#      ---------------------------------------- 49.9/49.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: holidays>=0.11.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (0.41)
# Requirement already satisfied: joblib>=0.16.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (3.8.0)
# Requirement already satisfied: nfoursid>=1.0.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.0.1)
# Requirement already satisfied: numpy>=1.19.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.26.2)
# Requirement already satisfied: pmdarima>=1.8.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (2.0.4)
# Requirement already satisfied: pyod>=0.9.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.1.2)
# Requirement already satisfied: requests>=2.22.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.11.4)
# Requirement already satisfied: shap>=0.40.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (0.44.0)
# Requirement already satisfied: statsforecast>=1.4 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.7.1)
# Requirement already satisfied: statsmodels>=0.14.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (0.14.0)
# Requirement already satisfied: tbats>=1.1.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.1.3)
# Requirement already satisfied: tqdm>=4.60.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (4.65.0)
# Requirement already satisfied: typing-extensions in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (4.9.0)
# Requirement already satisfied: xarray>=0.17.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (2023.6.0)
# Requirement already satisfied: xgboost>=1.6.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (2.0.3)
# Requirement already satisfied: pandas>=1.0.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from u8darts[notorch]) (1.5.3)
# Collecting prophet>=1.1.1 (from u8darts[notorch])
#   Downloading prophet-1.1.5-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting catboost>=1.0.6 (from u8darts[notorch])
#   Downloading catboost-1.2.2-cp310-cp310-win_amd64.whl.metadata (1.2 kB)
# Collecting lightgbm>=3.2.0 (from u8darts[notorch])
#   Downloading lightgbm-4.2.0-py3-none-win_amd64.whl.metadata (19 kB)
# Collecting graphviz (from catboost>=1.0.6->u8darts[notorch])
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.0 kB ? eta -:--:--
#      ---------------------------------------- 47.0/47.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: plotly in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from catboost>=1.0.6->u8darts[notorch]) (5.9.0)
# Requirement already satisfied: six in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from catboost>=1.0.6->u8darts[notorch]) (1.16.0)
# Requirement already satisfied: python-dateutil in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from holidays>=0.11.1->u8darts[notorch]) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->u8darts[notorch]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pandas>=1.0.5->u8darts[notorch]) (2023.3.post1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pmdarima>=1.8.0->u8darts[notorch]) (3.0.8)
# Requirement already satisfied: urllib3 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pmdarima>=1.8.0->u8darts[notorch]) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pmdarima>=1.8.0->u8darts[notorch]) (68.2.2)
# Collecting cmdstanpy>=1.0.4 (from prophet>=1.1.1->u8darts[notorch])
#   Downloading cmdstanpy-1.2.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: importlib-resources in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from prophet>=1.1.1->u8darts[notorch]) (6.1.1)
# Requirement already satisfied: numba>=0.51 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pyod>=0.9.5->u8darts[notorch]) (0.58.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->u8darts[notorch]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->u8darts[notorch]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->u8darts[notorch]) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from scikit-learn>=1.0.1->u8darts[notorch]) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from shap>=0.40.0->u8darts[notorch]) (0.0.7)
# Requirement already satisfied: cloudpickle in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from shap>=0.40.0->u8darts[notorch]) (2.2.1)
# Requirement already satisfied: fugue>=0.8.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from statsforecast>=1.4->u8darts[notorch]) (0.8.7)
# Requirement already satisfied: utilsforecast>=0.0.24 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from statsforecast>=1.4->u8darts[notorch]) (0.0.24)
# Requirement already satisfied: patsy>=0.5.2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from statsmodels>=0.14.0->u8darts[notorch]) (0.5.3)
# Requirement already satisfied: colorama in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from tqdm>=4.60.0->u8darts[notorch]) (0.4.6)
# Collecting stanio~=0.3.0 (from cmdstanpy>=1.0.4->prophet>=1.1.1->u8darts[notorch])
#   Downloading stanio-0.3.0-py3-none-any.whl.metadata (963 bytes)
# Requirement already satisfied: triad>=0.9.3 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (0.9.3)
# Requirement already satisfied: adagio>=0.2.4 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (0.2.0)
# Requirement already satisfied: sqlglot in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (20.9.0)
# Requirement already satisfied: jinja2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (3.1.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from numba>=0.51->pyod>=0.9.5->u8darts[notorch]) (0.41.0)
# Requirement already satisfied: tenacity>=6.2.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from plotly->catboost>=1.0.6->u8darts[notorch]) (8.2.2)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (4.11.1)
# Requirement already satisfied: pyarrow>=6.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (2023.10.0)
# Requirement already satisfied: fs in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (2.4.16)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from jinja2->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (2.1.1)
# Requirement already satisfied: appdirs~=1.4.3 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->u8darts[notorch]) (1.4.4)
# Downloading catboost-1.2.2-cp310-cp310-win_amd64.whl (101.0 MB)
#    ---------------------------------------- 0.0/101.0 MB ? eta -:--:--
#    ---------------------------------------- 0.6/101.0 MB 13.1 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    ---------------------------------------- 1.0/101.0 MB 13.3 MB/s eta 0:00:08
#    - -------------------------------------- 2.6/101.0 MB 1.8 MB/s eta 0:00:55
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.2/101.0 MB 2.9 MB/s eta 0:00:34
#    - -------------------------------------- 4.7/101.0 MB 2.6 MB/s eta 0:00:37
#    -- ------------------------------------- 6.7/101.0 MB 3.6 MB/s eta 0:00:26
#    --- ------------------------------------ 9.4/101.0 MB 5.0 MB/s eta 0:00:19
#    ---- ----------------------------------- 11.9/101.0 MB 18.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 14.1/101.0 MB 19.2 MB/s eta 0:00:05
#    ------ --------------------------------- 16.8/101.0 MB 54.7 MB/s eta 0:00:02
#    ------- -------------------------------- 19.6/101.0 MB 54.7 MB/s eta 0:00:02
#    -------- ------------------------------- 21.6/101.0 MB 50.4 MB/s eta 0:00:02
#    --------- ------------------------------ 23.8/101.0 MB 50.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 25.8/101.0 MB 46.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 28.8/101.0 MB 50.4 MB/s eta 0:00:02
#    ------------ --------------------------- 31.3/101.0 MB 50.4 MB/s eta 0:00:02
#    ------------- -------------------------- 33.9/101.0 MB 54.4 MB/s eta 0:00:02
#    ------------- -------------------------- 34.7/101.0 MB 46.9 MB/s eta 0:00:02
#    -------------- ------------------------- 36.8/101.0 MB 46.9 MB/s eta 0:00:02
#    --------------- ------------------------ 39.8/101.0 MB 46.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 42.6/101.0 MB 46.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 44.0/101.0 MB 50.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 44.6/101.0 MB 36.4 MB/s eta 0:00:02
#    ------------------ --------------------- 47.9/101.0 MB 46.7 MB/s eta 0:00:02
#    ------------------- -------------------- 49.8/101.0 MB 43.5 MB/s eta 0:00:02
#    -------------------- ------------------- 51.4/101.0 MB 38.6 MB/s eta 0:00:02
#    -------------------- ------------------- 51.9/101.0 MB 34.4 MB/s eta 0:00:02
#    --------------------- ------------------ 53.8/101.0 MB 32.8 MB/s eta 0:00:02
#    --------------------- ------------------ 54.8/101.0 MB 34.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 55.8/101.0 MB 34.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 56.8/101.0 MB 31.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 57.8/101.0 MB 27.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 58.8/101.0 MB 25.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 59.9/101.0 MB 24.3 MB/s eta 0:00:02
#    ------------------------ --------------- 60.9/101.0 MB 23.4 MB/s eta 0:00:02
#    ------------------------ --------------- 61.9/101.0 MB 24.2 MB/s eta 0:00:02
#    ------------------------ --------------- 62.9/101.0 MB 23.4 MB/s eta 0:00:02
#    ------------------------- -------------- 63.9/101.0 MB 21.8 MB/s eta 0:00:02
#    ------------------------- -------------- 64.9/101.0 MB 21.8 MB/s eta 0:00:02
#    -------------------------- ------------- 66.0/101.0 MB 21.8 MB/s eta 0:00:02
#    -------------------------- ------------- 67.0/101.0 MB 22.5 MB/s eta 0:00:02
#    -------------------------- ------------- 68.0/101.0 MB 21.9 MB/s eta 0:00:02
#    --------------------------- ------------ 69.1/101.0 MB 22.6 MB/s eta 0:00:02
#    --------------------------- ------------ 70.1/101.0 MB 22.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 71.1/101.0 MB 21.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 72.1/101.0 MB 21.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 73.1/101.0 MB 21.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 74.2/101.0 MB 21.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 75.2/101.0 MB 21.8 MB/s eta 0:00:02
#    ------------------------------ --------- 76.7/101.0 MB 22.6 MB/s eta 0:00:02
#    ------------------------------- -------- 80.2/101.0 MB 31.2 MB/s eta 0:00:01
#    -------------------------------- ------- 82.6/101.0 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 86.0/101.0 MB 65.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 88.4/101.0 MB 65.6 MB/s eta 0:00:01
#    ------------------------------------ --- 91.0/101.0 MB 54.4 MB/s eta 0:00:01
#    ------------------------------------- -- 93.7/101.0 MB 59.5 MB/s eta 0:00:01
#    ------------------------------------- -- 94.4/101.0 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------- -- 95.0/101.0 MB 40.9 MB/s eta 0:00:01
#    -------------------------------------- - 97.3/101.0 MB 38.6 MB/s eta 0:00:01
#    --------------------------------------  100.2/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------  101.0/101.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------------- 101.0/101.0 MB 17.2 MB/s eta 0:00:00
# Downloading lightgbm-4.2.0-py3-none-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 42.8 MB/s eta 0:00:00
# Downloading prophet-1.1.5-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/13.3 MB 44.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.0/13.3 MB 42.3 MB/s eta 0:00:01
#    ------------- -------------------------- 4.4/13.3 MB 35.2 MB/s eta 0:00:01
#    --------------------- ------------------ 7.2/13.3 MB 38.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.5/13.3 MB 40.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.9/13.3 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 34.4 MB/s eta 0:00:00
# Downloading u8darts-0.27.2-py3-none-any.whl (819 kB)
#    ---------------------------------------- 0.0/819.6 kB ? eta -:--:--
#    --------------------------------------- 819.6/819.6 kB 25.3 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.0-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.0 kB ? eta -:--:--
#    ---------------------------------------- 93.0/93.0 kB ? eta 0:00:00
# Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Installing collected packages: stanio, graphviz, lightgbm, cmdstanpy, catboost, prophet, u8darts
# Successfully installed catboost-1.2.2 cmdstanpy-1.2.0 graphviz-0.20.1 lightgbm-4.2.0 prophet-1.1.5 stanio-0.3.0 u8darts-0.27.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
import numpy as np
import pandas as pd
import shutil

from darts import TimeSeries
from darts.models import NHiTSModel, TiDEModel, TFTModel, TCNModel, ARIMA, BlockRNNModel, XGBModel, ExponentialSmoothing
from darts.datasets import AusBeerDataset
from darts.dataprocessing.transformers.scaler import Scaler
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from darts.metrics import mae, mse

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)

# %%
import copy
from pathlib import Path

# List of columns you want to read
selected_columns = ["Timestamp [s]", "CPU usage [%]", "Memory usage [%]"]

file_path = 'VM001.csv'
df = pd.read_csv(file_path, usecols=selected_columns)
df.head(-1)
# Out:
#               Timestamp [s]  CPU usage [%]  Memory usage [%]
# 0       2013-06-30 22:03:00       0.000000          6.500000
# 1       2013-06-30 22:04:00       0.066578          6.536489
# 2       2013-06-30 22:05:00       0.157880          6.586528
# 3       2013-06-30 22:06:00       0.220217          6.620693
# 4       2013-06-30 22:07:00       0.259892          6.642437
# ...                     ...            ...               ...
# 239030  2013-12-13 21:53:00       5.958158         11.280959
# 239031  2013-12-13 21:54:00       6.337063         11.567609
# 239032  2013-12-13 21:55:00       7.714891         12.674611
# 239033  2013-12-13 21:56:00      10.173214         14.600788
# 239034  2013-12-13 21:57:00       6.841250         11.982732
#
# [239035 rows x 3 columns]

# %%
# Convert 'Timestamp [ms]' to datetime and set it as the index
df.set_index('Timestamp [s]', inplace=True)

# Specify the frequency of your time series (e.g., 'H' for hourly, 'D' for daily)
frequency = 'm'  # Replace 'your_frequency' with the appropriate frequency code

# Preserve the 'Timestamp [ms]' column
df['Timestamp [s]'] = df.index

# %%
df.head()
# Out:
#                      CPU usage [%]  Memory usage [%]        Timestamp [s]
# Timestamp [s]
# 2013-06-30 22:03:00       0.000000          6.500000  2013-06-30 22:03:00
# 2013-06-30 22:04:00       0.066578          6.536489  2013-06-30 22:04:00
# 2013-06-30 22:05:00       0.157880          6.586528  2013-06-30 22:05:00
# 2013-06-30 22:06:00       0.220217          6.620693  2013-06-30 22:06:00
# 2013-06-30 22:07:00       0.259892          6.642437  2013-06-30 22:07:00

# %%
# Create a Darts TimeSeries object
series = TimeSeries.from_dataframe(df, "Timestamp [s]", 'CPU usage [%]')

# Assuming 'series' is your TimeSeries object
train_size = int(len(series) * 0.1)  # Halve the training set

# Split the data
series = series[:train_size]

print(len(series))
# Out:
# 23903

# %%
train, temp = series.split_after(0.7)
val, test = temp.split_after(0.5)

plt.figure(figsize=(24, 6))
train.plot(label="train")
val.plot(label="val")
test.plot(label="test")
# Out:
# <Axes: xlabel='Timestamp [s]'>

# %%
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

scaler = Scaler()  # default uses sklearn's MinMaxScaler
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)

plt.figure(figsize=(24, 6))
train.plot()
val.plot()
test.plot()
# Out:
# <Axes: xlabel='Timestamp [s]'>

# %%
# Common parameters
common_model_args = {
    "input_chunk_length": 4320,
    "output_chunk_length": 2880,
    "optimizer_kwargs": {"lr": 1e-2},
    "pl_trainer_kwargs": {
        "gradient_clip_val": 1,
        "max_epochs": 20,
        "accelerator": "auto",
        "callbacks": [],
        "logger": None
    },
    "lr_scheduler_cls": torch.optim.lr_scheduler.ExponentialLR,
    "lr_scheduler_kwargs": {"gamma": 0.999},
    "likelihood": None,
    "save_checkpoints": True,
    "force_reset": True,
    "batch_size": 128,
    "random_state": 42,
}

# Define early stopping arguments
early_stopping_args = {
    "monitor": "val_loss",
    "patience": 3,
    "mode": "min",
    "strict": True,
    "verbose": True,
}

# Update your pl_trainer_kwargs
pl_trainer_kwargs = common_model_args["pl_trainer_kwargs"]


# Model-specific parameters
model_nhits_params = {
    "model_name": "nhits_cpu",
}

model_tide_params = {
    "model_name": "tide_cpu",
    "use_reversible_instance_norm": False,
}

model_tft_params = {
    "model_name": "tft_cpu",
    "add_relative_index": True,
    "hidden_size": 64
}

model_tcn_params = {
    "model_name": "tcn_cpu",
}

model_arima_params = {
    "p": 24, 
    "d": 2,
    "q": 4
}

model_lstm_params = {
    "model_name": "lstm_cpu",
    "model": "LSTM",
    "n_rnn_layers": 4
}

model_esmoothing_params = {
    "seasonal_periods": 24,
    "trend": "ModelMode.ADDITIVE",
}


# Define each model by merging common and model-specific parameters
model_nhits_cpu = NHiTSModel(**common_model_args, **model_nhits_params)
model_tide_cpu = TiDEModel(**common_model_args, **model_tide_params)
model_tft_cpu = TFTModel(**common_model_args, **model_tft_params)
model_tcn_cpu = TCNModel(**common_model_args, **model_tcn_params)
model_arima_cpu = ARIMA(**model_arima_params)
model_lstm_cpu = BlockRNNModel(**common_model_args, **model_lstm_params)
model_esmoothing_cpu = ExponentialSmoothing(**model_esmoothing_params)


models = {
    #"NHiTS": model_nhits_cpu,
    #"TiDE": model_tide_cpu,
    #"TFT": model_tft_cpu,
    #"TCN": model_tcn_cpu,
    "ARIMA": model_arima_cpu,
    #"LSTM": model_lstm_cpu,
    #"Exponential Smoothing": model_esmoothing_cpu
}

# %%
# Saving the model to disk
import pickle

# Set the log directory where logs will be saved
log_dir = "logs"

# Create a TensorBoardLogger
logger = TensorBoardLogger(log_dir, name="bitbrains_all_models")

# Update your pl_trainer_kwargs
pl_trainer_kwargs["logger"] = logger

# Train the models and load the model from its best state/checkpoint
for name, model in models.items():
    # early stopping needs to get reset for each model
    pl_trainer_kwargs["callbacks"] = [
        EarlyStopping(
            **early_stopping_args,
        )
    ]

    # Use the logger in the Trainer (remove 'logger' from Trainer arguments)
    pl_trainer = pl.Trainer(**pl_trainer_kwargs)

    model.fit(
        series=train,
        #val_series=val,
        #verbose=True,
    )
    # load from checkpoint returns a new model object, we store it in the models dict
    #models[name] = model.load_from_checkpoint(model_name=model.model_name, best=True)
    model.save(f"models/{name}_bitbrains_cpu.pt")

# %%
pred = model.predict(2880)
pred.plot()
# Out:
# <Axes: xlabel='Timestamp [s]'>

# %%
from darts.metrics import quantile_loss

# we will predict the next `pred_steps` points after the end of `pred_input`
pred_steps = common_model_args["output_chunk_length"] * 2
pred_input = test[:-pred_steps]

# Set the specific start date
start_date = pd.Timestamp("2013-12-11")
end_date = pd.Timestamp("2013-12-14")

fig, ax = plt.subplots(figsize=(15, 5))
# plt.xlim(start_date, end_date)

scaler.inverse_transform(pred_input).plot(label="input")
scaler.inverse_transform(test)[-pred_steps:].plot(label="ground truth", ax=ax)

result_accumulator = {}
# predict with each model and compute/store the metrics against the test sets
for model_name, model in models.items():
    pred_series = model.predict(n=pred_steps)
    scaler.inverse_transform(pred_series).plot(label=model_name, ax=ax)

    result_accumulator[model_name] = {
        "mae": mae(test, pred_series),
        "mse": mse(test, pred_series)
    }
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 14
#      11 fig, ax = plt.subplots(figsize=(15, 5))
#      12 # plt.xlim(start_date, end_date)
# ---> 14 scaler.inverse_transform(pred_input).plot(label="input")
#      15 scaler.inverse_transform(test)[-pred_steps:].plot(label="ground truth", ax=ax)
#      17 result_accumulator = {}
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\darts\dataprocessing\transformers\invertible_data_transformer.py:330, in InvertibleDataTransformer.inverse_transform(self, series, component_mask, *args, **kwargs)
#     321     kwargs["component_mask"] = component_mask
#     323 input_iterator = _build_tqdm_iterator(
#     324     zip(data, self._get_params(n_timeseries=len(data))),
#     325     verbose=self._verbose,
#     326     desc=desc,
#     327     total=len(data),
#     328 )
# --> 330 transformed_data = _parallel_apply(
#     331     input_iterator,
#     332     self.__class__.ts_inverse_transform,
#     333     self._n_jobs,
#     334     args,
#     335     kwargs,
#     336 )
#     338 if self._mask_components:
#     339     unmasked = []
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\darts\utils\utils.py:209, in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     184 def _parallel_apply(
#     185     iterator: Iterator[Tuple], fn: Callable, n_jobs: int, fn_args, fn_kwargs
#     186 ) -> List:
#     187     """
#     188     Utility function that parallelise the execution of a function over an Iterator
#     189
#    (...)
#     206
#     207     """
# --> 209     returned_data = Parallel(n_jobs=n_jobs)(
#     210         delayed(fn)(*sample, *fn_args, **fn_kwargs) for sample in iterator
#     211     )
#     212     return returned_data
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\darts\dataprocessing\transformers\scaler.py:132, in Scaler.ts_inverse_transform(series, params, *args, **kwargs)
#     126 @staticmethod
#     127 def ts_inverse_transform(
#     128     series: TimeSeries, params: Mapping[str, Any], *args, **kwargs
#     129 ) -> TimeSeries:
#     130     transformer = params["fitted"]
# --> 132     tr_out = transformer.inverse_transform(Scaler.stack_samples(series))
#     133     inv_transformed_vals = Scaler.unstack_samples(tr_out, series=series)
#     135     return series.with_values(inv_transformed_vals)
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\sklearn\preprocessing\_data.py:544, in MinMaxScaler.inverse_transform(self, X)
#     530 """Undo the scaling of X according to feature_range.
#     531
#     532 Parameters
#    (...)
#     540     Transformed data.
#     541 """
#     542 check_is_fitted(self)
# --> 544 X = check_array(
#     545     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     546 )
#     548 X -= self.min_
#     549 X /= self.scale_
#
# File F:\Software\Anaconda\envs\deeplearning-env\lib\site-packages\sklearn\utils\validation.py:967, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     965     n_samples = _num_samples(array)
#     966     if n_samples < ensure_min_samples:
# --> 967         raise ValueError(
#     968             "Found array with %d sample(s) (shape=%s) while a"
#     969             " minimum of %d is required%s."
#     970             % (n_samples, array.shape, ensure_min_samples, context)
#     971         )
#     973 if ensure_min_features > 0 and array.ndim == 2:
#     974     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
results_df = pd.DataFrame.from_dict(result_accumulator, orient="index")
results_df.head()
# Out:
#           mae       mse
# TCN  0.071806  0.006882

# %%
pred_df = pred_series.pd_dataframe()

# %%
pred_df.head(-1)
# Out:
# component            CPU usage [%]
# Timestamp [s]
# 2013-12-09 21:59:00       0.140837
# 2013-12-09 22:00:00       0.142607
# 2013-12-09 22:01:00       0.139660
# 2013-12-09 22:02:00       0.153624
# 2013-12-09 22:03:00       0.121751
# ...                            ...
# 2013-12-13 21:53:00       0.061563
# 2013-12-13 21:54:00       0.099427
# 2013-12-13 21:55:00       0.123423
# 2013-12-13 21:56:00       0.123695
# 2013-12-13 21:57:00       0.130896
#
# [5759 rows x 1 columns]
