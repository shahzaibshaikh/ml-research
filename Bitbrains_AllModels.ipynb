# %%
# %cd "F:\University\Master's Thesis\Datasets\rnd"
# Out:
# F:\University\Master's Thesis\Datasets\rnd

# %%
# %pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.27.1-py3-none-any.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.3 kB ? eta -:--:--
#      ---------------------------------------- 48.3/48.3 kB 2.5 MB/s eta 0:00:00
# Collecting holidays>=0.11.1 (from darts)
#   Downloading holidays-0.41-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: joblib>=0.16.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (1.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (3.8.0)
# Collecting nfoursid>=1.0.0 (from darts)
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.19.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (1.26.2)
# Collecting pmdarima>=1.8.0 (from darts)
#   Downloading pmdarima-2.0.4-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Collecting pyod>=0.9.5 (from darts)
#   Downloading pyod-1.1.2.tar.gz (160 kB)
#      ---------------------------------------- 0.0/160.5 kB ? eta -:--:--
#      ------------------------------------- 160.5/160.5 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.22.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (1.11.4)
# Collecting shap>=0.40.0 (from darts)
#   Downloading shap-0.44.0-cp310-cp310-win_amd64.whl.metadata (24 kB)
# Collecting statsforecast>=1.4 (from darts)
#   Downloading statsforecast-1.7.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: statsmodels>=0.14.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (0.14.0)
# Collecting tbats>=1.1.0 (from darts)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#      ---------------------------------------- 44.0/44.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.60.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (4.65.0)
# Requirement already satisfied: typing-extensions in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (4.9.0)
# Requirement already satisfied: xarray>=0.17.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (2023.6.0)
# Collecting xgboost>=1.6.0 (from darts)
#   Downloading xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (2.1.3)
# Requirement already satisfied: tensorboardX>=2.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (2.1.2)
# Requirement already satisfied: pandas>=1.0.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from darts) (1.5.3)
# Requirement already satisfied: python-dateutil in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from matplotlib>=3.3.0->darts) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pandas>=1.0.5->darts) (2023.3.post1)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima>=1.8.0->darts)
#   Downloading Cython-3.0.8-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pmdarima>=1.8.0->darts) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pmdarima>=1.8.0->darts) (68.2.2)
# Requirement already satisfied: numba>=0.51 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pyod>=0.9.5->darts) (0.58.1)
# Requirement already satisfied: six in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pyod>=0.9.5->darts) (1.16.0)
# Requirement already satisfied: PyYAML>=5.4 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (2023.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (1.2.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from pytorch-lightning>=1.5.0->darts) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->darts) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from requests>=2.22.0->darts) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from scikit-learn>=1.0.1->darts) (2.2.0)
# Collecting slicer==0.0.7 (from shap>=0.40.0->darts)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: cloudpickle in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from shap>=0.40.0->darts) (2.2.1)
# Collecting fugue>=0.8.1 (from statsforecast>=1.4->darts)
#   Downloading fugue-0.8.7-py3-none-any.whl.metadata (17 kB)
# Collecting utilsforecast>=0.0.24 (from statsforecast>=1.4->darts)
#   Downloading utilsforecast-0.0.24-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: patsy>=0.5.2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from statsmodels>=0.14.0->darts) (0.5.3)
# Requirement already satisfied: protobuf>=3.20 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from tensorboardX>=2.1->darts) (4.23.4)
# Requirement already satisfied: filelock in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from torch>=1.8.0->darts) (3.13.1)
# Requirement already satisfied: sympy in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from torch>=1.8.0->darts) (1.12)
# Requirement already satisfied: networkx in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from torch>=1.8.0->darts) (3.1)
# Requirement already satisfied: jinja2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from torch>=1.8.0->darts) (3.1.2)
# Requirement already satisfied: colorama in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from tqdm>=4.60.0->darts) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (3.9.0)
# Collecting triad>=0.9.3 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading triad-0.9.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting qpd>=0.4.4 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading qpd-0.4.4-py3-none-any.whl.metadata (6.4 kB)
# Collecting fugue-sql-antlr>=0.1.6 (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading fugue-sql-antlr-0.2.0.tar.gz (154 kB)
#      ---------------------------------------- 0.0/154.7 kB ? eta -:--:--
#      -------------------------------------- 154.7/154.7 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting sqlglot (from fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading sqlglot-20.9.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.41.0)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from jinja2->torch>=1.8.0->darts) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from sympy->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->darts) (4.0.3)
# Collecting antlr4-python3-runtime<4.12 (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#      -------------------------------------- 144.2/144.2 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->darts) (6.0.1)
# Collecting fs (from triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->darts)
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ---------------------------------------- 0.0/135.3 kB ? eta -:--:--
#      -------------------------------------- 135.3/135.3 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: appdirs~=1.4.3 in f:\software\anaconda\envs\deeplearning-env\lib\site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)
# Downloading darts-0.27.1-py3-none-any.whl (817 kB)
#    ---------------------------------------- 0.0/817.6 kB ? eta -:--:--
#    ------------------------ -------------- 522.2/817.6 kB 16.5 MB/s eta 0:00:01
#    --------------------------------------  809.0/817.6 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 817.6/817.6 kB 8.7 MB/s eta 0:00:00
# Downloading holidays-0.41-py3-none-any.whl (913 kB)
#    ---------------------------------------- 0.0/913.1 kB ? eta -:--:--
#    -------------------------------- ------ 768.0/913.1 kB 24.4 MB/s eta 0:00:01
#    --------------------------------------- 913.1/913.1 kB 14.6 MB/s eta 0:00:00
# Downloading pmdarima-2.0.4-cp310-cp310-win_amd64.whl (613 kB)
#    ---------------------------------------- 0.0/613.3 kB ? eta -:--:--
#    --------------------------------------- 613.3/613.3 kB 19.5 MB/s eta 0:00:00
# Downloading shap-0.44.0-cp310-cp310-win_amd64.whl (447 kB)
#    ---------------------------------------- 0.0/448.0 kB ? eta -:--:--
#    --------------------------- ------------ 307.2/448.0 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 448.0/448.0 kB 6.9 MB/s eta 0:00:00
# Downloading statsforecast-1.7.1-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.1 kB ? eta -:--:--
#    ---------------------------------------- 118.1/118.1 kB 6.7 MB/s eta 0:00:00
# Downloading xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.7/99.8 MB 15.1 MB/s eta 0:00:07
#     --------------------------------------- 1.7/99.8 MB 21.3 MB/s eta 0:00:05
#    - -------------------------------------- 2.6/99.8 MB 20.8 MB/s eta 0:00:05
#    - -------------------------------------- 2.9/99.8 MB 17.1 MB/s eta 0:00:06
#    - -------------------------------------- 3.3/99.8 MB 15.2 MB/s eta 0:00:07
#    - -------------------------------------- 3.4/99.8 MB 14.7 MB/s eta 0:00:07
#    - -------------------------------------- 3.4/99.8 MB 14.7 MB/s eta 0:00:07
#    - -------------------------------------- 3.5/99.8 MB 10.0 MB/s eta 0:00:10
#    - -------------------------------------- 3.6/99.8 MB 9.3 MB/s eta 0:00:11
MB 20.5 MB/s eta 0:00:01
#    ------------------------------------ --- 92.0/99.8 MB 19.8 MB/s eta 0:00:01
#    ------------------------------------ --- 92.1/99.8 MB 17.7 MB/s eta 0:00:01
#    ------------------------------------- -- 92.5/99.8 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------- -- 93.3/99.8 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------- -- 94.2/99.8 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------- -- 94.5/99.8 MB 15.2 MB/s eta 0:00:01
#    -------------------------------------- - 95.3/99.8 MB 14.9 MB/s eta 0:00:01
#    -------------------------------------- - 95.8/99.8 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 96.7/99.8 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 96.7/99.8 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 96.9/99.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  97.6/99.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  98.0/99.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  98.3/99.8 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  98.8/99.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  99.4/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 7.7 MB/s eta 0:00:00
# Downloading Cython-3.0.8-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.8 MB 18.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.8 MB 18.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.8 MB 18.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.8 MB 3.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.2/2.8 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 8.4 MB/s eta 0:00:00
# Downloading fugue-0.8.7-py3-none-any.whl (279 kB)
#    ---------------------------------------- 0.0/279.8 kB ? eta -:--:--
#    --------------------------------------- 279.8/279.8 kB 16.8 MB/s eta 0:00:00
# Downloading utilsforecast-0.0.24-py3-none-any.whl (38 kB)
# Downloading qpd-0.4.4-py3-none-any.whl (169 kB)
#    ---------------------------------------- 0.0/169.2 kB ? eta -:--:--
#    ---------------------------------------- 169.2/169.2 kB 9.9 MB/s eta 0:00:00
# Downloading triad-0.9.3-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#    ---------------------------------------- 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# Downloading sqlglot-20.9.0-py3-none-any.whl (352 kB)
#    ---------------------------------------- 0.0/352.1 kB ? eta -:--:--
#    --------------------------------------- 352.1/352.1 kB 21.4 MB/s eta 0:00:00
# Building wheels for collected packages: pyod, fugue-sql-antlr
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.1.2-py3-none-any.whl size=190431 sha256=cbf77d045c0bb3df949c634864b62cca5d20efc14360844e114d6146a37df834
#   Stored in directory: c:\users\shahzaib shaikh\appdata\local\pip\cache\wheels\81\1b\61\aa85b78c3c0c8871f4231e3f4a03bb23cecb7db829498380ee
#   Building wheel for fugue-sql-antlr (setup.py): started
#   Building wheel for fugue-sql-antlr (setup.py): finished with status 'done'
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.2.0-py3-none-any.whl size=158214 sha256=eb1e0430c4a2984f93f9c1bd31cfb90d1d79cbbe173ef3838cce25ed0aa379e5
#   Stored in directory: c:\users\shahzaib shaikh\appdata\local\pip\cache\wheels\5a\b5\4e\216953a1c711da55de29ed7ecf158b4a5bf32ef93d69ad66dd
# Successfully built pyod fugue-sql-antlr
# Installing collected packages: antlr4-python3-runtime, sqlglot, slicer, fs, Cython, xgboost, holidays, utilsforecast, triad, shap, pyod, nfoursid, pmdarima, fugue-sql-antlr, adagio, tbats, qpd, fugue, statsforecast, darts
# Successfully installed Cython-3.0.8 adagio-0.2.4 antlr4-python3-runtime-4.11.1 darts-0.27.1 fs-2.4.16 fugue-0.8.7 fugue-sql-antlr-0.2.0 holidays-0.41 nfoursid-1.0.1 pmdarima-2.0.4 pyod-1.1.2 qpd-0.4.4 shap-0.44.0 slicer-0.0.7 sqlglot-20.9.0 statsforecast-1.7.1 tbats-1.1.3 triad-0.9.3 utilsforecast-0.0.24 xgboost-2.0.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
import numpy as np
import pandas as pd
import shutil

from darts import TimeSeries
from darts.models import NHiTSModel, TiDEModel, TFTModel, TCNModel, RNNModel
from darts.datasets import AusBeerDataset
from darts.dataprocessing.transformers.scaler import Scaler
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from darts.metrics import mae, mse

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)

# %%
import copy
from pathlib import Path

# List of columns you want to read
selected_columns = ["Timestamp [s]", "CPU usage [%]", "Memory usage [%]"]

file_path = 'VM001.csv'
df = pd.read_csv(file_path, usecols=selected_columns)
df.head(-1)
# Out:
#               Timestamp [s]  CPU usage [%]  Memory usage [%]
# 0       2013-06-30 22:03:00       0.000000          6.500000
# 1       2013-06-30 22:04:00       0.066578          6.536489
# 2       2013-06-30 22:05:00       0.157880          6.586528
# 3       2013-06-30 22:06:00       0.220217          6.620693
# 4       2013-06-30 22:07:00       0.259892          6.642437
# ...                     ...            ...               ...
# 239030  2013-12-13 21:53:00       5.958158         11.280959
# 239031  2013-12-13 21:54:00       6.337063         11.567609
# 239032  2013-12-13 21:55:00       7.714891         12.674611
# 239033  2013-12-13 21:56:00      10.173214         14.600788
# 239034  2013-12-13 21:57:00       6.841250         11.982732
#
# [239035 rows x 3 columns]

# %%
# Convert 'Timestamp [ms]' to datetime and set it as the index
df.set_index('Timestamp [s]', inplace=True)

# Specify the frequency of your time series (e.g., 'H' for hourly, 'D' for daily)
frequency = 'm'  # Replace 'your_frequency' with the appropriate frequency code

# Preserve the 'Timestamp [ms]' column
df['Timestamp [s]'] = df.index

# %%
df.head()
# Out:
#                      CPU usage [%]  Memory usage [%]        Timestamp [s]
# Timestamp [s]
# 2013-06-30 22:03:00       0.000000          6.500000  2013-06-30 22:03:00
# 2013-06-30 22:04:00       0.066578          6.536489  2013-06-30 22:04:00
# 2013-06-30 22:05:00       0.157880          6.586528  2013-06-30 22:05:00
# 2013-06-30 22:06:00       0.220217          6.620693  2013-06-30 22:06:00
# 2013-06-30 22:07:00       0.259892          6.642437  2013-06-30 22:07:00

# %%
# Create a Darts TimeSeries object
series = TimeSeries.from_dataframe(df, "Timestamp [s]", 'CPU usage [%]')

# %%
train, temp = series.split_after(0.7)
val, test = temp.split_after(0.5)

plt.figure(figsize=(24, 6))
train.plot(label="train")
val.plot(label="val")
test.plot(label="test")
# Out:
# <Axes: xlabel='Timestamp [s]'>

# %%
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

scaler = Scaler()  # default uses sklearn's MinMaxScaler
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)

plt.figure(figsize=(24, 6))
train.plot()
val.plot()
test.plot()
# Out:
# <Axes: xlabel='Timestamp [s]'>

# %%
# Common parameters
common_model_args = {
    "input_chunk_length": 4320,
    "output_chunk_length": 2880,
    "optimizer_kwargs": {"lr": 1e-3},
    "pl_trainer_kwargs": {
        "gradient_clip_val": 1,
        "max_epochs": 20,
        "accelerator": "auto",
        "callbacks": [],
        "logger": None
    },
    "lr_scheduler_cls": torch.optim.lr_scheduler.ExponentialLR,
    "lr_scheduler_kwargs": {"gamma": 0.999},
    "likelihood": None,
    "save_checkpoints": True,
    "force_reset": True,
    "batch_size": 128,
    "random_state": 42,
}

# Define early stopping arguments
early_stopping_args = {
    "monitor": "val_loss",
    "patience": 3,
    "mode": "min",
    "strict": True,
    "verbose": True,
}

# Update your pl_trainer_kwargs
pl_trainer_kwargs = common_model_args["pl_trainer_kwargs"]


# Model-specific parameters
model_nhits_params = {
    "model_name": "nhits_cpu",
}

model_tide_params = {
    "model_name": "tide_cpu",
    "use_reversible_instance_norm": False,
}

model_tft_params = {
    "model_name": "tft_cpu",
    "add_relative_index": True,
    "hidden_size": 128
}

model_tcn_params = {
    "model_name": "tcn_cpu",
}

model_deepar_params = {
    "model_name": "deepar_cpu",
    "hidden_dim": 20,
    "n_rnn_layers": 2,
    "dropout": 0.2,
}

# Define each model by merging common and model-specific parameters
model_nhits_cpu = NHiTSModel(**common_model_args, **model_nhits_params)
model_tide_cpu = TiDEModel(**common_model_args, **model_tide_params)
model_tft_cpu = TFTModel(**common_model_args, **model_tft_params)
model_tcn_cpu = TCNModel(**common_model_args, **model_tcn_params)
model_deepar_cpu = RNNModel(**common_model_args, **model_tcn_params)


models = {
    #"NHiTS": model_nhits_cpu,
    #"TiDE": model_tide_cpu,
    #"TFT": model_tft_cpu,
    #"TCN": model_tcn_cpu,
    "DeepAR": model_deepar_cpu
}

# %%
# Saving the model to disk
import pickle

# Set the log directory where logs will be saved
log_dir = "logs"

# Create a TensorBoardLogger
logger = TensorBoardLogger(log_dir, name="bitbrains_all_models")

# Update your pl_trainer_kwargs
pl_trainer_kwargs["logger"] = logger

# Train the models and load the model from its best state/checkpoint
for name, model in models.items():
    # early stopping needs to get reset for each model
    pl_trainer_kwargs["callbacks"] = [
        EarlyStopping(
            **early_stopping_args,
        )
    ]

    # Use the logger in the Trainer (remove 'logger' from Trainer arguments)
    pl_trainer = pl.Trainer(**pl_trainer_kwargs)

    model.fit(
        series=train,
        val_series=val,
        verbose=True,
    )
    # load from checkpoint returns a new model object, we store it in the models dict
    models[name] = model.load_from_checkpoint(model_name=model.model_name, best=True)
    model.save(f"models/{name}_bitbrains_cpu.pt")
# Out:
# Sanity Checking: |                                               | 0/? [00:00<?, ?it/s]
# Training: |                                                      | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]
# Validation: |                                                    | 0/? [00:00<?, ?it/s]

# %%
model_tide_cpu = model_tide_cpu.load_from_checkpoint(model_name="tide_cpu", best=True)
model.save(f"models/TiDE_bitbrains_cpu.pt")

# %%
from darts.metrics import quantile_loss

# we will predict the next `pred_steps` points after the end of `pred_input`
pred_steps = common_model_args["output_chunk_length"] * 2
pred_input = test[:-pred_steps]

# Set the specific start date
start_date = pd.Timestamp("2013-12-11")
end_date = pd.Timestamp("2013-12-14")

fig, ax = plt.subplots(figsize=(15, 5))
# plt.xlim(start_date, end_date)

scaler.inverse_transform(pred_input).plot(label="input")
scaler.inverse_transform(test)[-pred_steps:].plot(label="ground truth", ax=ax)

result_accumulator = {}
# predict with each model and compute/store the metrics against the test sets
for model_name, model in models.items():
    pred_series = model.predict(n=pred_steps, series=pred_input)
    scaler.inverse_transform(pred_series).plot(label=model_name, ax=ax)

    result_accumulator[model_name] = {
        "mae": mae(test, pred_series),
        "mse": mse(test, pred_series)
    }
# Out:
# Predicting: |                                                    | 0/? [00:00<?, ?it/s]

# %%
# Load the saved model
loaded_model = NHiTSModel.load("models/NHiTS_bitbrains_cpu.pt")

# %%
from darts.metrics import quantile_loss

# we will predict the next `pred_steps` points after the end of `pred_input`
pred_steps = 2880 * 2
pred_input = test[:-pred_steps]

# Set the specific start date
start_date = pd.Timestamp("2013-12-11")
end_date = pd.Timestamp("2013-12-14")

fig, ax = plt.subplots(figsize=(15, 5))
# plt.xlim(start_date, end_date)

scaler.inverse_transform(pred_input).plot(label="input")
scaler.inverse_transform(test)[-pred_steps:].plot(label="ground truth", ax=ax)

result_accumulator = {}
# predict with each model and compute/store the metrics against the test sets

pred_series = loaded_model.predict(n=pred_steps, series=pred_input)
scaler.inverse_transform(pred_series).plot(label=model_name, ax=ax)

result_accumulator["NHiTs"] = {
    "mae": mae(test, pred_series),
    "mse": mse(test, pred_series)
}
# Out:
# Predicting: |                                                    | 0/? [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame.from_dict(result_accumulator, orient="index")
results_df.head()
# Out:
#           mae       mse
# TCN  0.071806  0.006882

# %%
pred_df = pred_series.pd_dataframe()

# %%
pred_df.head(-1)
# Out:
# component            CPU usage [%]
# Timestamp [s]
# 2013-12-09 21:59:00       0.140837
# 2013-12-09 22:00:00       0.142607
# 2013-12-09 22:01:00       0.139660
# 2013-12-09 22:02:00       0.153624
# 2013-12-09 22:03:00       0.121751
# ...                            ...
# 2013-12-13 21:53:00       0.061563
# 2013-12-13 21:54:00       0.099427
# 2013-12-13 21:55:00       0.123423
# 2013-12-13 21:56:00       0.123695
# 2013-12-13 21:57:00       0.130896
#
# [5759 rows x 1 columns]
